# %% [markdown]
# <a href="https://colab.research.google.com/github/AsitSrivastava06/Pandas/blob/main/EXperiment_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Experiment-9
# #Title-Study of Pandas Library
# ### NAME: ASIT SRIVASTAVA
# #### BATCH:A2
# #### PRN:25070123026

# %%
#Introduction
#Pandas : panel data
'''used for:
structure data
EDA
data cleaning'''
# Out:
# 'used for: \nstructure data\nEDA\ndata cleaning'

# %%
import pandas as pd
s=pd.Series([10,20,30,40])
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
#Create DataFrame
dat={
    "Name":["A","B","C"],
    "Marks":[85,90,78]
}
df = pd.DataFrame(dat)
df
# Out:
#   Name  Marks
# 0    A     85
# 1    B     90
# 2    C     78

# %%
df.head()
df.tail()
# Out:
#   Name  Marks
# 0    A     85
# 1    B     90
# 2    C     78

# %%
#Find the structure of the dataframe
df.shape
# Out:
# (3, 2)

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 6

# %%
#display column na name
df.columns
# Out:
# Index(['Name', 'Marks'], dtype='object')

# %%
#check data types of each column
df.dtypes
# Out:
# Name     object
# Marks     int64
# dtype: object

# %%
#Access Indivisual Column
df["Name"]
# Out:
# 0    A
# 1    B
# 2    C
# Name: Name, dtype: object

# %%
#Access Specific Row
df.loc[1]
# Out:
# Name      B
# Marks    90
# Name: 1, dtype: object

# %%
#Add a new column
df["Grade"]=["First class","Distinction","Second class"]
df
# Out:
#   Name  Marks         Grade
# 0    A     88   First class
# 1    B     90   Distinction
# 2    C     78  Second class

# %%
#Update Data in DataFrame
#Change marks of stuent A to 88.
df.loc[0,"Marks"]=88
df
# Out:
#   Name  Marks         Grade
# 0    A     88   First class
# 1    B     90   Distinction
# 2    C     78  Second class

# %%
#Delete a column
df.drop("Grade", axis=1, inplace=True)
df
# Out:
#   Name  Marks
# 0    A     88
# 1    B     90
# 2    C     78

# %%
#Perform basic statistical analysis
mean1=df["Marks"].mean()
mean1
# Out:
# np.float64(85.33333333333333)

# %%
median1=df["Marks"].median()
median1
# Out:
# 88.0

# %%
mode1=df["Marks"].mode()
mode1
# Out:
# 0    78
# 1    88
# 2    90
# Name: Marks, dtype: int64

# %%
max1=df["Marks"].max()
max1
# Out:
# 90

# %%
min1=df["Marks"].min()
min1
# Out:
# 78

# %%
#apply condition (filtering)
#display students scoring more than 80.
df[df["Marks"]>80]
# Out:
#   Name  Marks
# 0    A     88
# 1    B     90
